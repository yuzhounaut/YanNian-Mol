# %%
if __name__ == '__main__':
    # This comprehensive search key combines three concepts to find papers on
    # anti-aging compounds that extend lifespan in model animals.
    # It has been extended with more animal models and lifespan-related terms.
    
    key = '''
(
  # --- 概念一：抗衰老相关化合物 ---
  (
    "anti-aging"[tiab]
    OR "anti-ageing"[tiab]
    OR geroprotector*[tiab]
    OR geroprotective[tiab]
    OR senolytic*[tiab]
    OR senomorphic*[tiab]
    OR "longevity-promoting"[tiab]
    OR "calorie restriction mimetic"[tiab]
    OR "caloric restriction mimetic"[tiab]
  )
)
AND
(
  # --- 概念二：延长寿命相关术语 ---
  (
    lifespan[tiab]
    OR "life span"[tiab]
    OR longevity[tiab]
    OR survival[tiab]
    OR "lifespan extension"[tiab]
    OR "lifespan extended"[tiab]
    OR "extend lifespan"[tiab]
    OR "extends lifespan"[tiab]
    OR "prolongs lifespan"[tiab]
    OR "prolonged lifespan"[tiab]
  )
)
AND
(
  # --- 概念三：模型动物 ---
  (
    # 啮齿类
    (
      mouse[tiab] OR mice[tiab] OR rat[tiab]
      OR murine[tiab] OR rodent[tiab]
    )
    OR
    # 灵长类
    (
      primate*[tiab] OR "non-human primate"[tiab]
      OR monkey*[tiab] OR "cynomolgus monkey"[tiab]
      OR "macaca fascicularis"[tiab] OR "rhesus macaque"[tiab]
      OR "macaca mulatta"[tiab]
    )
    OR
    # 其他脊椎动物
    (
      dog[tiab] OR dogs[tiab] OR canine[tiab]
      OR killifish[tiab] OR zebrafish[tiab]
      OR "danio rerio"[tiab] OR "d. rerio"[tiab]
    )
    OR
    # 无脊椎动物
    (
      "c. elegans"[tiab] OR "caenorhabditis elegans"[tiab]
      OR nematode[tiab] OR worm[tiab] OR drosophila[tiab]
      OR "drosophila melanogaster"[tiab] OR "d. melanogaster"[tiab]
      OR "fruit fly"[tiab]
    )
    OR
    # 真菌
    (
      yeast[tiab] OR "saccharomyces cerevisiae"[tiab]
      OR "s. cerevisiae"[tiab]
    )
    OR
    # MeSH 主题词
    ("animals"[Mesh])
  )
)
    '''
